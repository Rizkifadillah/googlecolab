# %% [markdown]
# <a href="https://colab.research.google.com/github/Rizkifadillah/googlecolab/blob/main/data_science/S1/E10_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_path = '/content/drive/MyDrive/course_ipynb/Kumpulan_dataset/linear.csv'
df = pd.read_csv(df_path)
df
# Out:
#             X         y   tipe
# 0    0.490560  3.564196  data1
# 1    0.580862  3.883283  data1
# 2    0.777627  4.485467  data1
# 3    0.193498  2.715008  data1
# 4    0.284830  2.503560  data1
# ..        ...       ...    ...
# 195  0.473481  1.723587  data2
# 196  0.517086  1.812512  data2
# 197  0.215826  1.163678  data2
# 198  0.972825  3.010107  data2
# 199  0.016298  0.506461  data2
#
# [200 rows x 3 columns]

# %%
df1 = df[df.tipe == 'data1']
plt.scatter(df1.X, df1.y)

# %%
df2 = df[df.tipe == 'data2']
plt.scatter(df2.X, df2.y)

# %%
df1 = df[df.tipe == 'data1']
df2 = df[df.tipe == 'data2']
plt.scatter(df2.X, df2.y)
plt.scatter(df1.X, df1.y)

# %% [markdown]
# **Seaborn**

# %%
plt.figure(figsize=(6,6))
sns.scatterplot("X","y", data=df, hue="tipe")
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='X', ylabel='y'>

# %%
# Regresi
plt.figure(figsize=(6,6))
sns.lmplot("X","y", data=df, hue="tipe"); #lmplot
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(6,6))
sns.distplot(df1.y, bins=20) #menampilkan histogram
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='y', ylabel='Density'>

# %% [markdown]
# # **Seaborn & Pandas Dataframe**

# %% [markdown]
# ***Statistik Summery***

# %%
df_path = '/content/drive/MyDrive/course_ipynb/Kumpulan_dataset/cereal.csv'
df = pd.read_csv(df_path)
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# ***Missing Value dengan seaborn***

# %%
plt.figure(figsize=(6,6))
sns.heatmap(df.isna(), cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ***Correlation Heatmap***

# %%
plt.figure(figsize=(6,6))
sns.heatmap(df.corr(), cmap='bwr', cbar=False, vmin=-1, annot=True, square=True, fmt=".1f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ***Pairplot***

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue="shelf", vars=['calories', 'fat','rating'])

# %%
sns.pairplot(df, hue="shelf", vars=['calories', 'fat','rating'], kind='reg') #dengan regresi

# %%
# analisis 2 data
sns.jointplot("potass","fiber", data=df, marginal_kws={"bins": 25}, kind="reg")
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # **Data bertipe kategori**

# %% [markdown]
# ***Persebaran***

# %%
sns.catplot("mfr", "rating", data=df)
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# boxplot
sns.boxplot("mfr", "rating", data=df)
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='mfr', ylabel='rating'>

# %%
# violinplot
sns.violinplot("mfr", "rating", data=df)
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='mfr', ylabel='rating'>

# %% [markdown]
# ***Count***

# %%
sns.catplot("mfr", data=df, kind='count')
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot("mfr", data=df)
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='mfr', ylabel='count'>

# %%
sns.countplot("mfr", data=df, hue='shelf')
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='mfr', ylabel='count'>
