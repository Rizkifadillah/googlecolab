# %% [markdown]
# <a href="https://colab.research.google.com/github/Rizkifadillah/googlecolab/blob/main/AirBnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
airbnb = pd.read_csv('sample_data/AB_NYC_2019.csv')
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
airbnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# menghapus data yg duplikat

# %%
airbnb = airbnb.drop_duplicates()

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# melihat column  last review

# %%
airbnb['last_review']
# Out:
# 0        2018-10-19
# 1        2019-05-21
# 2               NaN
# 3        2019-07-05
# 4        2018-11-19
#             ...
# 48890           NaN
# 48891           NaN
# 48892           NaN
# 48893           NaN
# 48894           NaN
# Name: last_review, Length: 48895, dtype: object

# %% [markdown]
# mengubah type data last_review yg sebelumnya object menjadi datetime

# %%
# from datetime import datetime
airbnb['last_review'] = pd.to_datetime(airbnb['last_review'], format='%d/%m/%Y')
# df['tanggal'] = pd.to_datetime(df['tanggal'], format='%Y-%m-%d %H:%M:%S')


# Mengubah tipe data kolom menjadi string
# airbnb['last_review'] = airbnb['last_review'].astype(str)

# Mengubah tipe data pada kolom menjadi datetime
# airbnb['last_review'] = pd.to_datetime(airbnb['last_review'], infer_datetime_format=True)

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# Untuk last_review sudah selesai
# Selanjutnya Handle Missing Value

# %%
airbnb[airbnb['host_name'].isna()]
# Out:
#              id                                               name    host_id  \
# 360      100184                                          Bienvenue     526653
# 2700    1449546                            Cozy Studio in Flatbush    7779204
# 5745    4183989    SPRING in the City!! Zen-Style Tranquil Bedroom     919218
# 6075    4446862                 Charming Room in Prospect Heights!   23077718
# 6582    4763327                Luxurious, best location, spa inc'l   24576978
# 8163    6292866                          Modern Quiet Gem Near All   32722063
# 8257    6360224                    Sunny, Private room in Bushwick   33134899
# 8852    6786181                       R&S Modern Spacious Hideaway   32722063
# 9138    6992973                    1 Bedroom in Prime Williamsburg    5162530
# 9817    7556587                               Sunny Room in Harlem   39608626
# 14040  10709846                 Sunny, spacious room in Greenpoint    7822683
# ...

# %%
airbnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# menghapus data pada kolom host_name yang kosong

# %%
airbnb = airbnb[~airbnb['host_name'].isna()]
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48874 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48874 non-null  int64
#  1   name                            48858 non-null  object
#  2   host_id                         48874 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48874 non-null  object
#  5   neighbourhood                   48874 non-null  object
#  6   latitude                        48874 non-null  float64
#  7   longitude                       48874 non-null  float64
#  8   room_type                       48874 non-null  object
#  9   price                           48874 non-null  int64
#  10  minimum_nights                  48874 non-null  int64
#  11  number_of_reviews               48874 non-null  int64
# ...

# %% [markdown]
# Menghapus data dikolom name yg kosong

# %%
airbnb[airbnb['name'].isna()]
# Out:
#              id name   host_id host_name neighbourhood_group  \
# 2854    1615764  NaN   6676776     Peter           Manhattan
# 3703    2232600  NaN  11395220      Anna           Manhattan
# 5775    4209595  NaN  20700823     Jesse           Manhattan
# 5975    4370230  NaN  22686810   Michaël           Manhattan
# 6269    4581788  NaN  21600904     Lucie            Brooklyn
# 6567    4756856  NaN   1832442  Carolina            Brooklyn
# 6605    4774658  NaN  24625694      Josh           Manhattan
# 8841    6782407  NaN  31147528  Huei-Yin            Brooklyn
# 11963   9325951  NaN  33377685  Jonathan           Manhattan
# 12824   9787590  NaN  50448556    Miguel           Manhattan
# 13059   9885866  NaN  37306329  Juliette           Manhattan
# 13401  10052289  NaN  49522403   Vanessa            Brooklyn
# 15819  12797684  NaN  69715276       Yan           Manhattan
# 16071  12988898  NaN  71552588    Andrea               Bronx
# ...

# %%
airbnb = airbnb[~airbnb['name'].isna()]
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48858 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48858 non-null  int64
#  1   name                            48858 non-null  object
#  2   host_id                         48858 non-null  int64
#  3   host_name                       48858 non-null  object
#  4   neighbourhood_group             48858 non-null  object
#  5   neighbourhood                   48858 non-null  object
#  6   latitude                        48858 non-null  float64
#  7   longitude                       48858 non-null  float64
#  8   room_type                       48858 non-null  object
#  9   price                           48858 non-null  int64
#  10  minimum_nights                  48858 non-null  int64
#  11  number_of_reviews               48858 non-null  int64
# ...

# %% [markdown]
# *Menghapus data kosong pada kolom lat,long,room_type,price,*minimum_nights,number_of_reviews,calculate_host_listings_count,availability_365,city
# *`italicized text`*
# > Indented block

# %%
# gajadi ganti datasetnya
# airbnb = airbnb[~airbnb['price'].isna()]
# airbnb.info()

# %% [markdown]
# Check Outliers

# %% [markdown]
# Mengidentifikasi Outliers dengan cara boxplot atau scatter plot

# %%
airbnb.boxplot(column='price')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Mengidentifikasi outlier dengan statistik deskriftif

# %%
airbnb['price'].describe()
# Out:
# count    48858.000000
# mean       152.740309
# std        240.232386
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %% [markdown]
# Dari mengidentifikasi dengan boxplot dan statistik deskriptif
# Kita sudah membuat enjugmen/ mengidentifikasikan bahwa data kita mengandung outliers

# %% [markdown]
# Cara membersihkan outliers dengan rumus statistik dibawah

# %% [markdown]
# Batas atas = Q3 + 1.5X(Q3-Q1), Batas bawah = Q1 - 1.5X(Q3-Q1)

# %%
# from numpy.lib.function_base import percentile
q1 = airbnb['price'].quantile(0.25)
q3 = airbnb['price'].quantile(0.75)
upper_limit = q3 + 1.5 * (q3-q1)
lower_limit = q1 + 1.5 * (q3-q1)

# %%
airbnb = airbnb[airbnb['price'] > lower_limit]
airbnb = airbnb[airbnb['price'] < upper_limit]
airbnb['price'].describe()
# Out:
# count    4064.000000
# mean      270.353839
# std        27.201173
# min       229.000000
# 25%       250.000000
# 50%       261.000000
# 75%       299.000000
# max       333.000000
# Name: price, dtype: float64

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4064 entries, 20 to 48872
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              4064 non-null   int64
#  1   name                            4064 non-null   object
#  2   host_id                         4064 non-null   int64
#  3   host_name                       4064 non-null   object
#  4   neighbourhood_group             4064 non-null   object
#  5   neighbourhood                   4064 non-null   object
#  6   latitude                        4064 non-null   float64
#  7   longitude                       4064 non-null   float64
#  8   room_type                       4064 non-null   object
#  9   price                           4064 non-null   int64
#  10  minimum_nights                  4064 non-null   int64
#  11  number_of_reviews               4064 non-null   int64
# ...

# %%
airbnb.boxplot(column='price')
# Out:
# <AxesSubplot:>

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4064 entries, 20 to 48872
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              4064 non-null   int64
#  1   name                            4064 non-null   object
#  2   host_id                         4064 non-null   int64
#  3   host_name                       4064 non-null   object
#  4   neighbourhood_group             4064 non-null   object
#  5   neighbourhood                   4064 non-null   object
#  6   latitude                        4064 non-null   float64
#  7   longitude                       4064 non-null   float64
#  8   room_type                       4064 non-null   object
#  9   price                           4064 non-null   int64
#  10  minimum_nights                  4064 non-null   int64
#  11  number_of_reviews               4064 non-null   int64
# ...

# %% [markdown]
# mengubah data float46(int) pada lat,long menjadi string(str)

# %%
airbnb['latitude'] = airbnb['latitude'].astype('str')
airbnb['longitude'] = airbnb['longitude'].astype('str')

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4064 entries, 20 to 48872
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              4064 non-null   int64
#  1   name                            4064 non-null   object
#  2   host_id                         4064 non-null   int64
#  3   host_name                       4064 non-null   object
#  4   neighbourhood_group             4064 non-null   object
#  5   neighbourhood                   4064 non-null   object
#  6   latitude                        4064 non-null   object
#  7   longitude                       4064 non-null   object
#  8   room_type                       4064 non-null   object
#  9   price                           4064 non-null   int64
#  10  minimum_nights                  4064 non-null   int64
#  11  number_of_reviews               4064 non-null   int64
# ...

# %% [markdown]
# Membuat kolom baru dengan lat,long

# %%
airbnb['Lat', 'Long'] = airbnb['latitude']+","+airbnb['longitude']
airbnb
# Out:
#              id                                               name    host_id  \
# 20         7801                   Sweet and Spacious Brooklyn Loft      21207
# 62        15711         2 bedroom - Upper East Side-great for kids      61491
# 68        16595  *HAVEN LOFT - Entire Floor - Six Windows - Bri...      64522
# 71        17037                            Lovely EV Artist's Home      66035
# 82        19169                   Entire 2 Bedroom - Large & Sunny      73128
# ...         ...                                                ...        ...
# 48784  36426319  Duplex penthouse with terrace, prime UES location   46876102
# 48785  36426720  Crash at a sofabed.Unique apt In the heart of NYC   67738361
# 48794  36428255  Skyscraper Ultimate Luxury at the Heart of BKLYN.  148289089
# 48799  36438336                                    Seas The Moment  211644523
# 48872  36476675                                      Nycity-MyHome    8636072
#
# ...

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4064 entries, 20 to 48872
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              4064 non-null   int64
#  1   name                            4064 non-null   object
#  2   host_id                         4064 non-null   int64
#  3   host_name                       4064 non-null   object
#  4   neighbourhood_group             4064 non-null   object
#  5   neighbourhood                   4064 non-null   object
#  6   latitude                        4064 non-null   object
#  7   longitude                       4064 non-null   object
#  8   room_type                       4064 non-null   object
#  9   price                           4064 non-null   int64
#  10  minimum_nights                  4064 non-null   int64
#  11  number_of_reviews               4064 non-null   int64
# ...

# %% [markdown]
# Mengubah tipe data id

# %%
airbnb['id'] = airbnb['id'].astype('str')
airbnb['host_id'] = airbnb['host_id'].astype('str')

# %% [markdown]
# Mengecek data apakah sudah bagus atau belum

# %%
airbnb['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
airbnb['room_type'].unique()
# Out:
# array(['Entire home/apt', 'Private room', 'Shared room'], dtype=object)

# %%
airbnb['name'].unique()
# Out:
# array(['Sweet and Spacious Brooklyn Loft',
#        '2 bedroom - Upper East Side-great for kids',
#        '*HAVEN LOFT - Entire Floor - Six Windows - Bricks*', ...,
#        'Skyscraper Ultimate Luxury at the Heart of BKLYN.',
#        'Seas The Moment', 'Nycity-MyHome'], dtype=object)

# %% [markdown]
# Save hasil dari clear dataset sebelumnya

# %%
airbnb.to_csv('airbnb_cleared_dataset.csv')

from google.colab import files
files.download('airbnb_cleared_dataset.csv')
